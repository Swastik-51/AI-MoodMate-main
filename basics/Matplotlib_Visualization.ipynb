# %% [markdown]
# # Data Visualization with Matplotlib
#
# This notebook contains comprehensive examples of data visualization techniques using Matplotlib. The examples progress from basic plotting to advanced 3D visualizations.
#
# ## Prerequisites
# ```bash
# pip install matplotlib numpy
# ```
#
# ## Table of Contents
# 1. [Basic Plotting](#basic)
# 2. [Specialized Plot Types](#specialized)
# 3. [Advanced Visualization](#advanced)

# %% [markdown]
# ## 1. Basic Plotting <a id="basic"></a>
#
# ### Simple Line Plot
# The most basic form of plotting - connecting data points with lines.

# %%
import matplotlib.pyplot as plt

# Data
x = [1, 2, 3, 4,5]
y = [2, 4, 6, 8, 10]

# Plot
plt.plot(x, y)
plt.show()

# %% [markdown]
# ### Enhanced Line Plot with Labels and Styling
# Adding titles, axis labels, legends, and custom colors to make plots more informative.

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [1, 4, 9, 16, 25]

plt.plot(x, y, label="y = x^2", color="red")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Basic Line Plot")
plt.legend()
plt.show()

# %% [markdown]
# ### Multiple Line Plots
# Comparing different mathematical functions on the same axes.

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y1 = [i for i in x]
y2 = [i**2 for i in x]
y3 = [i**3 for i in x]

plt.plot(x, y1, label="y = x")
plt.plot(x, y2, label="y = x^2")
plt.plot(x, y3, label="y = x^3")
plt.legend()
plt.show()

# %% [markdown]
# ## 2. Specialized Plot Types <a id="specialized"></a>
#
# ### Scatter Plot
# Display individual data points to show relationships and correlations between variables.

# %%
import matplotlib.pyplot as plt

x = [5, 7, 8, 7, 6, 9, 5, 6]
y = [99, 86, 87, 88, 100, 86, 103, 87]

plt.scatter(x, y, color="green", marker="o", s=100)  # s = size
plt.title("Scatter Plot Example")
plt.xlabel("X values")
plt.ylabel("Y values")
plt.show()

# %% [markdown]
# ### Bar Chart
# Compare categorical data with vertical bars.

# %%
import matplotlib.pyplot as plt

x = ["A", "B", "C", "D", "E"]
y = [3, 7, 8, 5, 4]

plt.bar(x, y, color="orange")
plt.title("Bar Chart Example")
plt.show()

# %% [markdown]
# ### Histogram
# Show the distribution of numerical data by grouping values into bins.

# %%
import matplotlib.pyplot as plt
import numpy as np

data = np.random.randn(1000)  # 1000 random numbers

plt.hist(data, bins=30, color="purple", edgecolor="black")
plt.title("Histogram Example")
plt.show()

# %% [markdown]
# ### Pie Chart
# Show proportional data as segments of a circle.

# %%
import matplotlib.pyplot as plt

sizes = [20, 30, 25, 25]
labels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(sizes, labels=labels, autopct="%1.1f%%", startangle=90)
plt.title("Pie Chart Example")
plt.show()

# %% [markdown]
# ## 3. Advanced Visualization <a id="advanced"></a>
#
# ### Subplots
# Display multiple plots in a single figure for comparison.

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [i**2 for i in x]

plt.subplot(1, 2, 1)  # 1 row, 2 cols, 1st plot
plt.plot(x, y, "r-")
plt.title("Line Plot")

plt.subplot(1, 2, 2)  # 1 row, 2 cols, 2nd plot
plt.bar(x, y)
plt.title("Bar Plot")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Customized Plot Styling
# Advanced customization with line styles, markers, grids, and other visual elements.

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [2, 5, 7, 1, 6]

plt.plot(x, y, color="blue", linestyle="--", marker="o", linewidth=2, markersize=8)
plt.grid(True)
plt.title("Customized Plot")
plt.show()

# %% [markdown]
# ### 3D Surface Plot
# Visualize three-dimensional data using surface plots with color mapping.

# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = fig.add_subplot(111, projection="3d")

x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
X, Y = np.meshgrid(x, y)
Z = np.sin(np.sqrt(X**2 + Y**2))

ax.plot_surface(X, Y, Z, cmap="viridis")
ax.set_title("3D Surface Plot")
plt.show()

# %% [markdown]
# ## Conclusion
#
# This notebook demonstrated various matplotlib visualization techniques:
#
# - **Basic Plotting**: Simple lines, enhanced styling, multiple series
# - **Specialized Charts**: Scatter plots, bar charts, histograms, pie charts
# - **Advanced Features**: Subplots, custom styling, 3D visualization
#
# ### Key Matplotlib Concepts Covered:
# - `plt.plot()` for line plots
# - `plt.scatter()` for scatter plots
# - `plt.bar()` for bar charts
# - `plt.hist()` for histograms
# - `plt.pie()` for pie charts
# - `plt.subplot()` for multiple plots
# - 3D plotting with `mplot3d`
#
# ### Best Practices:
# 1. Always add titles and axis labels for clarity
# 2. Use legends when plotting multiple series
# 3. Choose appropriate colors and markers for different data types
# 4. Use `plt.tight_layout()` for better subplot spacing
# 5. Consider your audience when choosing visualization types
#
# ### Next Steps:
# - Explore interactive plotting with Plotly
# - Learn statistical plotting with Seaborn
# - Practice with real-world datasets
# - Experiment with different color maps and styling options
